# %% [markdown]
# #Spiel(en) mit KI und Data Science
#
# ## Abgabe (Code, Dokumentation, Präsentation und Diskussion): Datum wird noch bekanntgegeben
#
#
#
# ### Aufgaben:
#
# Programmieren Sie (mit ihrem Team) in Python das folgende Spiel:
#
# m,n,k game (https://en.wikipedia.org/wiki/M,n,k-game)
#
# In der Variante: m=5, n=5, k=4
#
#
#
# #### Funktionierendes Python-Programm (40%) mit folgenden Elementen:
#
# - Spiel Mensch gegen Mensch
# - Spiel gegen Computer (Zufalls-KI)
# - Spiel gegen Computer (einfache KI, besser als Zufall)
# - Spiel gegen Computer (komplexere KI: z.B. über Spielbaum)
# - Spiel Computer vs. Computer
# - KI die mit anderen Gruppen integrierbar ist!
#
#
#
# Das Programm muss als funktionierender Python-Code vorliegen (ein oder mehrere .py Dateien).
#
#
#
# ### Dokumentation & Analyse (25%)
#
# - Projektdokumentation, bestehend aus:
#     - Spielregeln, Programm-Nutzung, Ablauf des Projekts (kurze Beschreibung des Projektverlaufs),
#     - Wer hat was gemacht, Programmaufbau, Erklärung des KI-Konzept, Fazit & Ausblick
#     - Data Science 1: Gibt es einen Vorteil/Nachteil für den/die Startspieler*In?
#     - Data Science 2: Statistischer Vergleich der verschiedenen KI’s.
#
# Die Dokumentation ist schriftlich abzugeben (als pdf-Datei).
#
#
#
# ### Code quality (10%)
#
# - Wichtige Elemente (z.B. Funktionen, Klassen) dokumentiert?
# - Lesbarer Code (sinnvolle Variablennamen, erkennbare Struktur etc.)
#
#
#
# ### Präsentation & Diskussion (25%)
#
# - Präsentation und Vorführung des Programms vor der Gruppe
# - Anschließende Diskussion des Projektes (jeweiliges Team + Florian Huber + David Sokalski)
#
#
# ### Erlaubte Mittel:
#
# Der Programmcode soll in Python erstellt werden. Es dürfen dazu auch die folgenden Python-
#
# Bibliotheken genutzt werden: Alle built-in modules (https://docs.python.org/3/py-modindex.html),
#
# sowie NumPy, SciPy, Pandas, Scikit-Learn. Darüber hinaus auch matplotlib, plotly, (Visualisierungs-
#
# Bibliotheken) und tkinter, PyQT, pysimplegui (Bibliotheken um GUI’s zu erstellen). Die Verwendung
#
# davon abweichender Bibliotheken benötigt die Zustimmung eines Projektbetreuers.
#
#
#
# ### Dokumentation
#
# Neben den oben aufgezählten Punkten muss in der Dokumentation für jede(n) Teilnehmer*Innen mit
#
# angegeben werden, bei welchen Aufgaben er/sie nennenswert beteiligt war, z.B:
#
# 1. Koordination / Planung
#
# 2. Konzept und Design
#
# 3. Programmierung, falls möglich auch in welchem Umfang und an welchen Teilen des Projektes.
#
# 4. Dokumentation
#
# 5. Vortrag
#
#
#
# ### Bestehen:
#
# \>= 50 Punkte
#
# Wenn ersichtlich wird, dass ein/e Teilnehmer*In nicht nennenswert zum Projekt beigetragen hat, gilt
#
# das Modul als nicht bestand

# %%
print("wer das liest, kann lesen")
# Out:
# wer das liest, kann lesen
